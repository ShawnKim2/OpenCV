# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import drive
drive.mount('/content/gdrive')
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/gdrive

# %%
img_path = '/content/gdrive/MyDrive/Colab Notebooks/Images/lena256.jpg'

origin_img = cv2.imread(img_path)
RGB_img = cv2.cvtColor(origin_img, cv2.COLOR_BGR2RGB)

cv2_imshow(origin_img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
img_path = '/content/gdrive/MyDrive/Colab Notebooks/Images/cell-bright.bmp'

origin_img = cv2.imread(img_path)
RGB_img = cv2.cvtColor(origin_img, cv2.COLOR_BGR2RGB)

cv2_imshow(origin_img)
# Out:
# <PIL.Image.Image image mode=RGB size=360x360>

# %%
T1 = 50
T2 = 0
T0 = 1

outimg = np.zeros((origin_img.shape[0], origin_img.shape[1]))

# %%
def threehold_update(h, w, img, output, T1):
  sum1 = 0
  count1 = 1
  sum2 = 0
  count2 = 1

  for h in range(img.shape[0]):
    for w in range(img.shape[1]):
        if(output[h,w]== 255):
          sum1 = sum1 + img[h,w]
          count1 = count1 + 1
